# %% [markdown]
# Setting Up Your Environment

# %%
pip install qiskit qiskit-aer matplotlib
# Out:
# Collecting qiskit
#   Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl.metadata (14 kB)
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 412.1 kB/s eta 0:00:00 0:00:01
# Collecting numpy<3,>=2.0 (from qiskit)
#   Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting scipy>=1.14 (from qiskit)
#   Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 2.4 MB/s eta 0:00:00
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (10 kB)
# Collecting dill>=0.3 (from qiskit)
#   Downloading dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Downloading stevedore-5.9.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: typing-extensions in ./medium_quantum_venv/lib/python3.12/site-packages (from qiskit) (4.16.0)
# Requirement already satisfied: psutil>=5 in ./medium_quantum_venv/lib/python3.12/site-packages (from qiskit-aer) (7.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in ./medium_quantum_venv/lib/python3.12/site-packages (from qiskit-aer) (2.9.0.post0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.28.2 (from matplotlib)
#   Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.7/118.7 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in ./medium_quantum_venv/lib/python3.12/site-packages (from matplotlib) (26.2)
# Collecting pillow>=9 (from matplotlib)
#   Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in ./medium_quantum_venv/lib/python3.12/site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Downloading qiskit-2.5.0-cp310-abi3-manylinux_2_28_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 5.3 MB/s eta 0:00:0000:0100:01
# Downloading qiskit_aer-0.17.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 6.8 MB/s eta 0:00:0000:0100:01
# Downloading matplotlib-3.11.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 13.1 MB/s eta 0:00:00 0:00:01
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 4.5 MB/s eta 0:00:00ta 0:00:01
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading dill-0.4.1-py3-none-any.whl (120 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.0/120.0 kB 34.7 MB/s eta 0:00:00
# Downloading fonttools-4.63.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 9.7 MB/s eta 0:00:00a 0:00:01m
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 27.2 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-2.5.1-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 13.5 MB/s eta 0:00:0000:0100:01
# Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 12.1 MB/s eta 0:00:0000:0100:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.8/122.8 kB 33.1 MB/s eta 0:00:00
# Downloading rustworkx-0.18.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 7.2 MB/s eta 0:00:0000:01:00:01
# Downloading scipy-1.18.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.3/35.3 MB 10.9 MB/s eta 0:00:0000:0100:01
# Downloading stevedore-5.9.0-py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 14.3 MB/s eta 0:00:00
# Installing collected packages: stevedore, pyparsing, pillow, numpy, kiwisolver, fonttools, dill, cycler, scipy, rustworkx, contourpy, qiskit, matplotlib, qiskit-aer
# Successfully installed contourpy-1.3.3 cycler-0.12.1 dill-0.4.1 fonttools-4.63.0 kiwisolver-1.5.0 matplotlib-3.11.1 numpy-2.5.1 pillow-12.3.0 pyparsing-3.3.2 qiskit-2.5.0 qiskit-aer-0.17.2 rustworkx-0.18.0 scipy-1.18.0 stevedore-5.9.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Import the Required Libraries

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# %% [markdown]
# Create a Quantum Circuit

# %%
qc = QuantumCircuit(1)

# %% [markdown]
# Apply the Hadamard Gate

# %%
qc.h(0)

# %% [markdown]
# Measure the qubit

# %%
qc.measure_all()

# %% [markdown]
# Visualise Your Circuit

# %%
print(qc.draw())
# Out:
#         ┌───┐ ░ ┌─┐
#      q: ┤ H ├─░─┤M├
#         └───┘ ░ └╥┘
# meas: 1/═════════╩═
#                  0

# %% [markdown]
# Run the Simulation

# %%
simulator = AerSimulator()
result = simulator.run(qc, shots=1000).result()
counts = result.get_counts()
print(counts)
# Out:
# {'0': 470, '1': 530}

# %% [markdown]
# Final Code

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

# Create a 1-qubit circuit
qc = QuantumCircuit(1)

# Apply Hadamard gate
qc.h(0)

# Measure the qubit
qc.measure_all()

# Visualise the circuit
print(qc.draw())

# Run the simulation
simulator = AerSimulator()
result = simulator.run(qc, shots=1000).result()
counts = result.get_counts()
print(counts)
# Out:
#         ┌───┐ ░ ┌─┐
#      q: ┤ H ├─░─┤M├
#         └───┘ ░ └╥┘
# meas: 1/═════════╩═
#                  0
# {'0': 491, '1': 509}
